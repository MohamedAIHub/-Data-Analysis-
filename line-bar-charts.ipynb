# %%
import pandas as pd
df =pd.read_csv("car_malfunctions.csv")
df
# Out:
#    Age  malfunctions  DaysOff
# 0    5             6       15
# 1   10            10       20
# 2   20            25       50
# 3   25            50      100
# 4   35            75      200
# 5   40            90      240

# %%
import matplotlib.pyplot as plt
data =df["malfunctions"]
plt.plot(data)
plt.show()

# %%
plt.plot(data, marker="o")
plt.show()

# %%
plt.plot(data, marker="*")
plt.show()

# %%
plt.plot(data, marker="*",ls =":")
plt.show()

# %%
plt.plot(data,ls =":")
plt.show()

# %%
df = pd.read_csv("car_malfunctions_2.csv")
x = df['Name']
y = df['Malfunctions']
plt.bar(x,y)
plt.show()

# %%
plt.barh(x,y)
plt.show()

# %%
plt.bar(x, y, width = 0.1)
plt.show()
