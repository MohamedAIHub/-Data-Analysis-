# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Students_exams.csv")
data
# Out:
#      gender  math score  reading score  writing score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# ..      ...         ...            ...            ...
# 995  female          88             99             95
# 996    male          62             55             55
# 997  female          59             71             65
# 998  female          68             78             77
# 999  female          77             86             86
#
# [1000 rows x 4 columns]

# %%
sns.barplot(x="gender",y="math score",data=data,color="red")
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
sns.barplot(x="gender",y="math score",data=data, palette = 'hls')
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_23128\1441163872.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="gender",y="math score",data=data, palette = 'hls')
# <Axes: xlabel='gender', ylabel='math score'>
