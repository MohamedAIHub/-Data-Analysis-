# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dds_datasets/dds_datasets/dds_ch2_nyt/nyt1.csv")
df
# Out:
#         Age  Gender  Impressions  Clicks  Signed_In
# 0        36       0            3       0          1
# 1        73       1            3       0          1
# 2        30       0            3       0          1
# 3        49       1            3       0          1
# 4        47       1           11       0          1
# ...     ...     ...          ...     ...        ...
# 458436    0       0            2       0          0
# 458437    0       0            4       0          0
# 458438   72       1            5       0          1
# 458439    0       0            5       0          0
# 458440    0       0            3       0          0
#
# [458441 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458441 entries, 0 to 458440
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Age          458441 non-null  int64
#  1   Gender       458441 non-null  int64
#  2   Impressions  458441 non-null  int64
#  3   Clicks       458441 non-null  int64
#  4   Signed_In    458441 non-null  int64
# dtypes: int64(5)
# memory usage: 17.5 MB

# %%
df.isnull().sum()
# Out:
# Age            0
# Gender         0
# Impressions    0
# Clicks         0
# Signed_In      0
# dtype: int64

# %%
df.columns = [col.lower() for col in df]
df
# Out:
#         age  gender  impressions  clicks  signed_in
# 0        36       0            3       0          1
# 1        73       1            3       0          1
# 2        30       0            3       0          1
# 3        49       1            3       0          1
# 4        47       1           11       0          1
# ...     ...     ...          ...     ...        ...
# 458436    0       0            2       0          0
# 458437    0       0            4       0          0
# 458438   72       1            5       0          1
# 458439    0       0            5       0          0
# 458440    0       0            3       0          0
#
# [458441 rows x 5 columns]

# %%
bins = [0, 18, 25, 35, 45, 55, 65, 110]
labels = ['<18', '18-24', '25-34', '35-44', '45-54', '55-64', '65+']
df['age_group'] = pd.cut(df.age, bins, labels = labels, include_lowest = True)
df
# Out:
#         age  gender  impressions  clicks  signed_in age_group
# 0        36       0            3       0          1     35-44
# 1        73       1            3       0          1       65+
# 2        30       0            3       0          1     25-34
# 3        49       1            3       0          1     45-54
# 4        47       1           11       0          1     45-54
# ...     ...     ...          ...     ...        ...       ...
# 458436    0       0            2       0          0       <18
# 458437    0       0            4       0          0       <18
# 458438   72       1            5       0          1       65+
# 458439    0       0            5       0          0       <18
# 458440    0       0            3       0          0       <18
#
# [458441 rows x 6 columns]

# %%
sns.countplot(x='age_group', hue='gender', data=df)
# Out:
# <Axes: xlabel='age_group', ylabel='count'>

# %%
sns.countplot(x='clicks', hue='age_group', data=df)
# Out:
# <Axes: xlabel='clicks', ylabel='count'>

# %%
sns.boxplot(y=df['impressions'], x=df['age_group'])
# Out:
# <Axes: xlabel='age_group', ylabel='impressions'>

# %%
df['CTR'] = round(df['clicks']/df['impressions'], 5)
sns.boxenplot(x=df['age_group'], y = df['CTR'])
# Out:
# <Axes: xlabel='age_group', ylabel='CTR'>

# %%
sns.countplot(x='age_group', hue='gender', data=df_Clicked)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.countplot(x='age_group', hue='gender', data=df_Clicked)
#
# NameError: name 'df_Clicked' is not defined
